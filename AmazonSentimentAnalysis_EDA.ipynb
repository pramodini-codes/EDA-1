# %%
import pandas as pd
import nltk

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import string
from nltk.tokenize import word_tokenize

# %%
df=pd.read_csv("/content/archive (1).zip")
df
# Out:
#         S No Category ProductRelease  PositiveReviews  CriticalReviews  \
# 0          1  Desktop      25-Sep-16               99               33
# 1          2  Desktop      25-Sep-16               99               33
# 2          3  Desktop      25-Sep-16               99               33
# 3          4  Desktop      25-Sep-16               99               33
# 4          5  Desktop      25-Sep-16               99               33
# ...      ...      ...            ...              ...              ...
# 40203  40204   Router       2-Aug-10             2565              970
# 40204  40205   Router       2-Aug-10             2565              970
# 40205  40206   Router       2-Aug-10             2565              970
# 40206  40207   Router       2-Aug-10             2565              970
# 40207  40208   Router       2-Aug-10             2565              970
#
#        TotalReviews  ProductRating  ReviewRating   \
# 0               132            4.0              1
# ...

# %%
stop_words=stopwords.words('english')
ps=PorterStemmer()

# %%
def preprocessing(text):
  text=text.lower()
  token=nltk.word_tokenize(text)
  new=[]
  for i in token:
    if i not in stop_words and i not in string.punctuation:
      stemmer=ps.stem(i)
      new.append(stemmer)
  return " ".join(new)

# %%
df["clean"]=df["ReviewBody"].apply(preprocessing)

# %%
df["clean"]
# Out:
# 0        advertis 2016 unit state 2013 top case check h...
# 1        well got 2 star reason realli 2 1/2 honestli c...
# 2        comput advertis 2016 model howev manufactur da...
# 3                           fine first day would n't start
# 4        right box mous n't work 's 10 mous bad start c...
#                                ...
# 40203                 perform high price brand name router
# 40204    good easi configur connect strong signal speed...
# 40205    router much better netgear full recept everywh...
# 40206                                             easi set
# 40207    arriv time work first time plug problem good s...
# Name: clean, Length: 40208, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vector=TfidfVectorizer()
X=vector.fit_transform(df["clean"])
y=df["ReviewStatus"]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=55)

# %%
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
print("train accuracy",log.score(X_train,y_train))
print("test accuracy",log.score(X_test,y_test))
# Out:
# train accuracy 0.900266477171789
# test accuracy 0.8774765812816049

# %%
def pred_text(text):
  text=text.lower()
  text=preprocessing(text)
  vec=vector.transform([text])
  prediction=log.predict(vec)[0]
  if prediction == 'Positive':
    return 'positive'
  else:
    return 'negative'

# %%
print(pred_text("Easy to set it up."))
# Out:
# positive

# %%
print(pred_text("Did not work. Returned"))
# Out:
# negative

# %%
print(pred_text("Who sells a computer without WiFi nowadays? Disappointed."))
# Out:
# negative

# %%
print(pred_text("Good product!  Good vendor.  Awesome deal. Thank you!"))
# Out:
# positive

# %%
print(pred_text("This product is awesome!! I got way more then I thought I would for the money!"))
# Out:
# positive

# %%
print(pred_text("I am crying"))
# Out:
# negative

# %%
print(pred_text("I am happy"))
# Out:
# positive

# %%
print(pred_text("damaged computer."))
# Out:
# negative
