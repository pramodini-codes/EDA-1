# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('/content/archive.zip',encoding='unicode_escape')
df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
print("Shape:", df.shape)
# Out:
# Shape: (2938, 22)

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
pd.isnull(df).sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
print("\nData Types:")
print(df.dtypes)
# Out:
# Data Types:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# ...

# %%
df['Population'].dtypes
# Out:
# dtype('float64')

# %%
df['Population']=df['Population'].astype('int')

# %%
df['Population'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
print("\nColumns:")
print(df.columns)
# Out:
# Columns:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
print("\nColumns:",df.columns)
# Out:
# Columns: Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
df.rename(columns={'Income composition of resources':'Income'})
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  1649.000000       1649.000000      1649.000000    1649.000000
# mean   2007.840509         69.302304       168.215282      32.553062
# std       4.087711          8.796834       125.310417     120.847190
# min    2000.000000         44.000000         1.000000       0.000000
# 25%    2005.000000         64.400000        77.000000       1.000000
# 50%    2008.000000         71.700000       148.000000       3.000000
# 75%    2011.000000         75.000000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1600.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  1649.000000             1649.000000  1649.000000    1649.000000
# mean      4.533196              698.973558    79.217708    2224.494239
# std       4.029189             1759.229336    25.604664   10085.802019
# ...

# %%
df[['Year','infant deaths','GDP','Population']].describe()
# Out:
#               Year  infant deaths            GDP    Population
# count  1649.000000    1649.000000    1649.000000  1.649000e+03
# mean   2007.840509      32.553062    5566.031887  1.465363e+07
# std       4.087711     120.847190   11475.900117  7.046039e+07
# min    2000.000000       0.000000       1.681350  3.400000e+01
# 25%    2005.000000       1.000000     462.149650  1.918970e+05
# 50%    2008.000000       3.000000    1592.572182  1.419631e+06
# 75%    2011.000000      22.000000    4718.512910  7.658972e+06
# max    2015.000000    1600.000000  119172.741800  1.293859e+09

# %%
a=sns.countplot(x='Status',data=df)
for bars in a.containers:
  a.bar_label(bars)

# %%
ax=sns.countplot(data=df,x='Year',hue='Status')
sns.set(rc={'figure.figsize':(25,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %%
a=df.groupby(['Status'],as_index=False)['Life expectancy'].mean().sort_values(by='Life expectancy',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Status',y='Life expectancy')
# Out:
# <Axes: xlabel='Status', ylabel='Life expectancy'>

# %%
a=df.groupby(['Status'],as_index=False)['Schooling'].mean().sort_values(by='Schooling',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Status',y='Schooling')
# Out:
# <Axes: xlabel='Status', ylabel='Schooling'>

# %%
a=df.groupby(['Status'],as_index=False)['GDP'].sum().sort_values(by='GDP',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Status',y='GDP')
# Out:
# <Axes: xlabel='Status', ylabel='GDP'>

# %%
a=df.groupby(['Status'],as_index=False)['GDP'].mean().sort_values(by='GDP',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Status',y='GDP')
# Out:
# <Axes: xlabel='Status', ylabel='GDP'>

# %%
a=df.groupby(['Status'],as_index=False)['Adult Mortality'].mean().sort_values(by='Adult Mortality',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Status',y='Adult Mortality')
# Out:
# <Axes: xlabel='Status', ylabel='Adult Mortality'>

# %%
a=df.groupby(['Status'],as_index=False)['BMI'].mean().sort_values(by='BMI',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Status',y='BMI',data=a)
# Out:
# <Axes: xlabel='Status', ylabel='BMI'>

# %%
a=df.groupby(['Status'],as_index=False)['Alcohol'].mean().sort_values(by='Alcohol',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Status',y='Alcohol',data=a)
# Out:
# <Axes: xlabel='Status', ylabel='Alcohol'>

# %%
ax=sns.countplot(x='Year',data=df)
for bars in ax.containers:
  ax.bar_label(bars)

# %%
ax=sns.countplot(data=df,x='Status',hue='Year')
sns.set(rc={'figure.figsize':(25,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %%
a=df.groupby(['Year'],as_index=False)['Life expectancy'].mean().sort_values(by='Life expectancy',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Year',y='Life expectancy')
# Out:
# <Axes: xlabel='Year', ylabel='Life expectancy'>

# %%
a = df.groupby('Year', as_index=False)['Life expectancy'].mean()
sns.barplot(data=a, x='Year', y='Life expectancy')
# Out:
# <Axes: xlabel='Year', ylabel='Life expectancy'>

# %%
a=df.groupby(['Year'],as_index=False)['Adult Mortality'].mean().sort_values(by='Adult Mortality',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Year',y='Adult Mortality')
# Out:
# <Axes: xlabel='Year', ylabel='Adult Mortality'>

# %%
a = df.groupby('Year', as_index=False)['Adult Mortality'].mean()
sns.barplot(data=a, x='Year', y='Adult Mortality')
# Out:
# <Axes: xlabel='Year', ylabel='Adult Mortality'>

# %%
a=df.groupby(['Year'],as_index=False)['GDP'].mean().sort_values(by='GDP',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Year',y='GDP')
# Out:
# <Axes: xlabel='Year', ylabel='GDP'>

# %%
a=df.groupby(['Year'],as_index=False)['Schooling'].mean().sort_values(by='Schooling',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Year',y='Schooling')
# Out:
# <Axes: xlabel='Year', ylabel='Schooling'>

# %%
a=df.groupby(['Year'],as_index=False)['BMI'].mean().sort_values(by='BMI',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Year',y='BMI')
# Out:
# <Axes: xlabel='Year', ylabel='BMI'>

# %%
a=df.groupby(['Year'],as_index=False)['Alcohol'].mean().sort_values(by='Alcohol',ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Year',y='Alcohol')
# Out:
# <Axes: xlabel='Year', ylabel='Alcohol'>

# %%
top_10_countries = df['Country'].value_counts().head(10).index
ax = sns.countplot(x='Country', data=df[df['Country'].isin(top_10_countries)], order=top_10_countries)
sns.set(rc={'figure.figsize':(100,20)})
for bars in ax.containers:
  ax.bar_label(bars)

# %%
a=df.groupby(['Country'],as_index=False)['Life expectancy'].mean().sort_values(by='Life expectancy',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Country',y='Life expectancy')
# Out:
# <Axes: xlabel='Country', ylabel='Life expectancy'>

# %%
a=df.groupby(['Country'],as_index=False)['GDP'].mean().sort_values(by='GDP',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Country',y='GDP')
# Out:
# <Axes: xlabel='Country', ylabel='GDP'>

# %%
a=df.groupby(['Country'],as_index=False)['GDP'].sum().sort_values(by='GDP',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Country',y='GDP')
# Out:
# <Axes: xlabel='Country', ylabel='GDP'>

# %%
a=df.groupby(['Country'],as_index=False)['Schooling'].mean().sort_values(by='Schooling',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Country',y='Schooling')
# Out:
# <Axes: xlabel='Country', ylabel='Schooling'>

# %%
a=df.groupby(['Country'],as_index=False)['BMI'].mean().sort_values(by='BMI',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Country',y='BMI')
# Out:
# <Axes: xlabel='Country', ylabel='BMI'>

# %%
a=df.groupby(['Country'],as_index=False)['Adult Mortality'].mean().sort_values(by='Adult Mortality',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=a,x='Country',y='Adult Mortality')
# Out:
# <Axes: xlabel='Country', ylabel='Adult Mortality'>
